# %% [markdown]
# ## Data Cleaning
# In this file we have cleaned and checked if we need to perform any data preprocessing in the scraped data.

# %%
#importing required modules
import pandas as pd
import numpy as np

# %%
#reading 
data = pd.read_csv('data/ODI_Players_runs.csv',sep=',')

# %%
#creating a copy of dataset
data_temp = data.copy()

# %%
data_temp.head()
# Out:
#                                                 Name  1970  1971  1972  1973  \
# 0  Zaheer Abbas (Pakistan)\r\n            - ODI C...   NaN   NaN   NaN   NaN
# 1  Syed Abid Ali (India)\r\n            - ODI Cri...   NaN   NaN   NaN   NaN
# 2  Jimmy Adams (West Indies)\r\n            - ODI...   NaN   NaN   NaN   NaN
# 3  Jonathan Agnew (England)\r\n            - ODI ...   NaN   NaN   NaN   NaN
# 4  Saliya Ahangama (Sri Lanka)\r\n            - O...   NaN   NaN   NaN   NaN
#
#    1974   1975  1976  1977  1978  ...  2010  2011  2012  2013  2014  2015  \
# 0  88.0  136.0  23.0  10.0  91.0  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1  23.0   70.0   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN    NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN    NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN    NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2016  2017  2018  2019
# 0   NaN   NaN   NaN   NaN
# ...

# %%
data_temp.shape
# Out:
# (2547, 51)

# %%
new = data_temp["Name"].str.split("(", n = 1, expand = True)

# %%
name = new[0]

# %%
country = new[1].str.split(")", n = 1, expand = True)[0]

# %%
data_temp.insert(loc=0, column='Name_of_player', value=name)
data_temp.insert(loc=1, column='Country', value=country)

# %%
data_temp.drop(['Name'],axis=1,inplace=True)

# %%
data_temp.head()
# Out:
#      Name_of_player      Country  1970  1971  1972  1973  1974   1975  1976  \
# 0     Zaheer Abbas      Pakistan   NaN   NaN   NaN   NaN  88.0  136.0  23.0
# 1    Syed Abid Ali         India   NaN   NaN   NaN   NaN  23.0   70.0   NaN
# 2      Jimmy Adams   West Indies   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 3   Jonathan Agnew       England   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 4  Saliya Ahangama     Sri Lanka   NaN   NaN   NaN   NaN   NaN    NaN   NaN
#
#    1977  ...  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# 0  10.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 52 columns]

# %%
data_temp.drop_duplicates(inplace=True)

# %%
data_temp.to_csv('data/ODI_Players_runs_Cleaned.csv',sep=',',index=False)

# %%
odi_players = data_temp[['Name_of_player','Country']]

# %%
odi_players.to_csv('data/ODI_Players.csv',sep=',',index=False)
